# %% [markdown]
# ## Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(10, 60, (50))
print(x)
# Out:
# [26 12 39 34 18 37 50 33 14 22 25 24 24 57 34 40 44 52 30 17 44 53 17 28
#  37 24 11 15 11 45 31 22 35 55 32 39 21 24 15 29 41 45 23 13 47 53 27 37
#  29 35]

# %%
num = [26, 12, 39, 34, 18, 37, 50, 33, 14, 22, 25, 24, 24, 57, 34, 40, 44, 52, 30,
       17, 44, 53, 17, 28, 37, 24, 11, 15, 11, 45, 31, 22, 35, 55, 32, 39, 21, 24,
       15, 29, 41, 45, 23, 13, 47, 53, 27, 37, 29, 35]

plt.hist(num)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

num = [26, 12, 39, 34, 18, 37, 50, 33, 14, 22, 25, 24, 24, 57, 34, 40, 44, 52, 30,
       17, 44, 53, 17, 28, 37, 24, 11, 15, 11, 45, 31, 22, 35, 55, 32, 39, 21, 24,
       15, 29, 41, 45, 23, 13, 47, 53, 27, 37, 29, 35]

l = [10, 20, 30, 40, 50, 60]
plt.hist(num, color = 'g', edgecolor = 'black')

plt.title("Histogram")
plt.xlabel("USN")
plt.ylabel("Score")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

num = [26, 12, 39, 34, 18, 37, 50, 33, 14, 22, 25, 24, 24, 57, 34, 40, 44, 52, 30,
       17, 44, 53, 17, 28, 37, 24, 11, 15, 11, 45, 31, 22, 35, 55, 32, 39, 21, 24,
       15, 29, 41, 45, 23, 13, 47, 53, 27, 37, 29, 35]

l = [10, 20, 30, 40, 50, 60]
plt.hist(num, color = 'g', bins = l, edgecolor = 'black')

plt.title("Histogram")
plt.xlabel("USN")
plt.ylabel("Score")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

num = [26, 12, 39, 34, 18, 37, 50, 33, 14, 22, 25, 24, 24, 57, 34, 40, 44, 52, 30,
       17, 44, 53, 17, 28, 37, 24, 11, 15, 11, 45, 31, 22, 35, 55, 32, 39, 21, 24,
       15, 29, 41, 45, 23, 13, 47, 53, 27, 37, 29, 35]

l = [10, 20, 30, 40, 50, 60]
plt.hist(num, "auto", (0, 100), edgecolor = 'black') # (0, 100) reprsents range

plt.title("Histogram")
plt.xlabel("USN")
plt.ylabel("Score")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

num = [26, 12, 39, 34, 18, 37, 50, 33, 14, 22, 25, 24, 24, 57, 34, 40, 44, 52, 30,
       17, 44, 53, 17, 28, 37, 24, 11, 15, 11, 45, 31, 22, 35, 55, 32, 39, 21, 24,
       15, 29, 41, 45, 23, 13, 47, 53, 27, 37, 29, 35]

l = [10, 20, 30, 40, 50, 60]
plt.hist(num, color = 'cyan', edgecolor = 'black', cumulative = -1)

plt.title("Histogram")
plt.xlabel("USN")
plt.ylabel("Score")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

num = [26, 12, 39, 34, 18, 37, 50, 33, 14, 22, 25, 24, 24, 57, 34, 40, 44, 52, 30,
       17, 44, 53, 17, 28, 37, 24, 11, 15, 11, 45, 31, 22, 35, 55, 32, 39, 21, 24,
       15, 29, 41, 45, 23, 13, 47, 53, 27, 37, 29, 35]

l = [10, 20, 30, 40, 50, 60]
plt.hist(num, color = 'cyan', edgecolor = 'black', bottom = 20, align = 'left')

plt.title("Histogram")
plt.xlabel("USN")
plt.ylabel("Score")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

num = [26, 12, 39, 34, 18, 37, 50, 33, 14, 22, 25, 24, 24, 57, 34, 40, 44, 52, 30,
       17, 44, 53, 17, 28, 37, 24, 11, 15, 11, 45, 31, 22, 35, 55, 32, 39, 21, 24,
       15, 29, 41, 45, 23, 13, 47, 53, 27, 37, 29, 35]

l = [10, 20, 30, 40, 50, 60]
plt.hist(num, color = 'cyan', bins = l, edgecolor = 'black', histtype = 'step')

plt.title("Histogram")
plt.xlabel("USN")
plt.ylabel("Score")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

num = [26, 12, 39, 34, 18, 37, 50, 33, 14, 22, 25, 24, 24, 57, 34, 40, 44, 52, 30,
       17, 44, 53, 17, 28, 37, 24, 11, 15, 11, 45, 31, 22, 35, 55, 32, 39, 21, 24,
       15, 29, 41, 45, 23, 13, 47, 53, 27, 37, 29, 35]

l = [10, 20, 30, 40, 50, 60]
plt.hist(num, color = 'cyan', bins = l, edgecolor = 'black', histtype = 'stepfilled')

plt.title("Histogram")
plt.xlabel("USN")
plt.ylabel("Score")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

num = [26, 12, 39, 34, 18, 37, 50, 33, 14, 22, 25, 24, 24, 57, 34, 40, 44, 52, 30,
       17, 44, 53, 17, 28, 37, 24, 11, 15, 11, 45, 31, 22, 35, 55, 32, 39, 21, 24,
       15, 29, 41, 45, 23, 13, 47, 53, 27, 37, 29, 35]

l = [10, 20, 30, 40, 50, 60]
plt.hist(num, color = 'cyan', bins = l, edgecolor = 'black', histtype = 'barstacked')

plt.title("Histogram")
plt.xlabel("USN")
plt.ylabel("Score")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

num = [26, 12, 39, 34, 18, 37, 50, 33, 14, 22, 25, 24, 24, 57, 34, 40, 44, 52, 30,
       17, 44, 53, 17, 28, 37, 24, 11, 15, 11, 45, 31, 22, 35, 55, 32, 39, 21, 24,
       15, 29, 41, 45, 23, 13, 47, 53, 27, 37, 29, 35]

l = [10, 20, 30, 40, 50, 60]
plt.hist(num, color = 'cyan', bins = l, edgecolor = 'black', orientation = 'horizontal')

plt.title("Histogram")
plt.xlabel("USN")
plt.ylabel("Score")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

num = [26, 12, 39, 34, 18, 37, 50, 33, 14, 22, 25, 24, 24, 57, 34, 40, 44, 52, 30,
       17, 44, 53, 17, 28, 37, 24, 11, 15, 11, 45, 31, 22, 35, 55, 32, 39, 21, 24,
       15, 29, 41, 45, 23, 13, 47, 53, 27, 37, 29, 35]

l = [10, 20, 30, 40, 50, 60]
plt.hist(num, color = 'cyan', bins = l, edgecolor = 'black', log = True, label = 'Shik Shak Sho')

plt.title("Histogram")
plt.xlabel("USN")
plt.ylabel("Score")

plt.axvline(35, color = 'gray', label = 'Line')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

num = [26, 12, 39, 34, 18, 37, 50, 33, 14, 22, 25, 24, 24, 57, 34, 40, 44, 52, 30,
       17, 44, 53, 17, 28, 37, 24, 11, 15, 11, 45, 31, 22, 35, 55, 32, 39, 21, 24,
       15, 29, 41, 45, 23, 13, 47, 53, 27, 37, 29, 35]

l = [10, 20, 30, 40, 50, 60]
plt.hist(num, color = 'cyan', bins = l, edgecolor = 'black', log = True, label = 'Shik Shak Sho')

plt.title("Histogram")
plt.xlabel("USN")
plt.ylabel("Score")

plt.axvline(35, color = 'gray', label = 'Line')

plt.legend()
plt.grid()
plt.show()
